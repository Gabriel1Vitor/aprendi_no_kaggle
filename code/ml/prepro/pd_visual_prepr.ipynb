# %%
import numpy as np
import pandas as pd

# %%
train=pd.read_csv('/content/train.csv')
test=pd.read_csv('/content/test.csv')

# %%
#outro metodo de mostrar todos os elementos
train.info(1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69999 entries, 0 to 69998
# Data columns (total 172 columns):
#  #    Column                    Dtype
# ---   ------                    -----
#  0    id                        int64
#  1    circle_id                 int64
#  2    loc_og_t2o_mou            float64
#  3    std_og_t2o_mou            float64
#  4    loc_ic_t2o_mou            float64
#  5    last_date_of_month_6      object
#  6    last_date_of_month_7      object
#  7    last_date_of_month_8      object
#  8    arpu_6                    float64
#  9    arpu_7                    float64
#  10   arpu_8                    float64
#  11   onnet_mou_6               float64
#  12   onnet_mou_7               float64
#  13   onnet_mou_8               float64
#  14   offnet_mou_6              float64
#  15   offnet_mou_7              float64
#  16   offnet_mou_8              float64
#  17   roam_ic_mou_6             float64
#  18   roam_ic_mou_7             float64
# ...

# %%
#dropa todos as linhas com algum elemento NA
test1=test.dropna()

# %%
print('com NA',test.shape)
test.tail()
# Out:
# com NA (30000, 171)
#           id  circle_id  loc_og_t2o_mou  std_og_t2o_mou  loc_ic_t2o_mou  \
# 29995  99994        109             0.0             0.0             0.0
# 29996  99995        109             0.0             0.0             0.0
# 29997  99996        109             0.0             0.0             0.0
# 29998  99997        109             0.0             0.0             0.0
# 29999  99998        109             0.0             0.0             0.0
#
#       last_date_of_month_6 last_date_of_month_7 last_date_of_month_8  \
# 29995            6/30/2014            7/31/2014            8/31/2014
# 29996            6/30/2014            7/31/2014            8/31/2014
# 29997            6/30/2014            7/31/2014            8/31/2014
# 29998            6/30/2014            7/31/2014            8/31/2014
# 29999            6/30/2014            7/31/2014            8/31/2014
#
#          arpu_6   arpu_7  ...  sachet_3g_6  sachet_3g_7  sachet_3g_8  \
# ...

# %%
print('sem NA',test1.shape)
test1.tail()
# Out:
# sem NA (4407, 171)
#           id  circle_id  loc_og_t2o_mou  std_og_t2o_mou  loc_ic_t2o_mou  \
# 29962  99961        109             0.0             0.0             0.0
# 29985  99984        109             0.0             0.0             0.0
# 29987  99986        109             0.0             0.0             0.0
# 29990  99989        109             0.0             0.0             0.0
# 29999  99998        109             0.0             0.0             0.0
#
#       last_date_of_month_6 last_date_of_month_7 last_date_of_month_8   arpu_6  \
# 29962            6/30/2014            7/31/2014            8/31/2014  732.023
# 29985            6/30/2014            7/31/2014            8/31/2014  701.057
# 29987            6/30/2014            7/31/2014            8/31/2014  358.323
# 29990            6/30/2014            7/31/2014            8/31/2014  176.373
# 29999            6/30/2014            7/31/2014            8/31/2014  318.980
#
# ...

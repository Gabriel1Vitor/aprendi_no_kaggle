# %%
import numpy as np
import pandas as pd

# %%
st=pd.read_csv('/content/drive/MyDrive/State of Data 2021 - Dataset - Pgina1.csv')
st1=pd.read_csv('/content/drive/MyDrive/State_of_data_2022.csv')
# Out:
# <ipython-input-2-eda7ec518f31>:1: DtypeWarning: Columns (47) have mixed types. Specify dtype option on import or set low_memory=False.
#   st=pd.read_csv('/content/drive/MyDrive/State of Data 2021 - Dataset - Pgina1.csv')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

lista=["('P7_b_d ', 'Luigi')"]

lista1=["('P4_i_1 ', 'Microsoft PowerBI')","('P4_i_16 ', 'Looker')","('P4_i_17 ', 'Google Data Studio')",
        "('P4_i_3 ', 'Tableau')","('P4_i_2 ', 'Qlik View/Qlik Sense')"]

a=st[lista]
b=st1[lista1]

a2=pd.DataFrame()
a2['PowerBi']=b["('P4_i_1 ', 'Microsoft PowerBI')"]

a3=pd.DataFrame()
a3['Tableau']=b["('P4_i_3 ', 'Tableau')"]

a4=pd.DataFrame()
a4['Looker']=b["('P4_i_16 ', 'Looker')"]

a5=pd.DataFrame()
a5['Qlik']=b["('P4_i_2 ', 'Qlik View/Qlik Sense')"]

a6=pd.DataFrame()
a6['DataStudio']=b["('P4_i_17 ', 'Google Data Studio')"]


a2['PowerBi']=a2.loc[a2['PowerBi'] ==1]
a2['Tableau']=a3.loc[a3['Tableau'] ==1]

a2['Looker']=a4.loc[a4['Looker'] ==1]

a2['Qlik']=a5.loc[a5['Qlik'] ==1]

a2['DataStudio']=a6.loc[a6['DataStudio'] ==1]
plt.hist(x=a2)
# Out:
# (array([[ 0.,  0.,  0.,  0.,  0., 97.,  0.,  0.,  0.,  0.],
#         [ 0.,  0.,  0.,  0.,  0., 35.,  0.,  0.,  0.,  0.],
#         [ 0.,  0.,  0.,  0.,  0., 20.,  0.,  0.,  0.,  0.],
#         [ 0.,  0.,  0.,  0.,  0.,  8.,  0.,  0.,  0.,  0.],
#         [ 0.,  0.,  0.,  0.,  0., 38.,  0.,  0.,  0.,  0.]]),
#  array([0.5, 0.6, 0.7, 0.8, 0.9, 1. , 1.1, 1.2, 1.3, 1.4, 1.5]),
#  <a list of 5 BarContainer objects>)

# %%
b.dropna()
b.columns=['PowerBi','Looker','DataStudio','Tableau','Qlik']
e1=pd.DataFrame(b.sum(axis=0))
e1.columns=['Usuarios']
e1.head()
# Out:
#             Usuarios
# PowerBi         97.0
# Looker          20.0
# DataStudio      38.0
# Tableau         35.0
# Qlik             8.0

# %%
b3=pd.DataFrame()
b3["('P7_b_4 ', 'Luigi')"]=st1["('P7_b_4 ', 'Luigi')"]

b3=b3.dropna()
print(b3.loc[b3["('P7_b_4 ', 'Luigi')"]==1.0])
print(a.loc[a["('P7_b_d ', 'Luigi')"] ==1])
# Out:
#       ('P7_b_4 ', 'Luigi')
# 1334                   1.0
#       ('P7_b_d ', 'Luigi')
# 1879                   1.0

# %%
b3["('P7_b_d ', 'Luigi')"] =a["('P7_b_d ', 'Luigi')"] 
b3.columns=['Luigi 2022','Luigi 2021']
e2=pd.DataFrame(b3.sum(axis=0))
e2.columns=['Usuario']
e2.head()
# Out:
#             Usuario
# Luigi 2022      1.0
# Luigi 2021      1.0

# %%
st1.filter(like="('P1_b ', 'Genero')",axis=1)
# Out:
#      ('P1_b ', 'Genero')
# 0              Masculino
# 1              Masculino
# 2              Masculino
# 3              Masculino
# 4               Feminino
# ...                  ...
# 4266           Masculino
# 4267            Feminino
# 4268           Masculino
# 4269           Masculino
# 4270           Masculino
#
# [4271 rows x 1 columns]

# %%
#juntar duas tabela com o pandas
statemaior=pd.concat([st,st1])

statemaior.tail(1)
# Out:
#                           ('P0', 'id')  ('P1_a ', 'Idade')  \
# 4270  00lb35llmdsidpa00lb35qcdysnzvhv7                24.0
#
#      ('P1_a_a ', 'Faixa idade') ('P1_b ', 'Genero')  \
# 4270                        NaN           Masculino
#
#      ('P1_e ', 'Estado onde mora') ('P1_e_a ', 'uf onde mora')  \
# 4270                           NaN                         NaN
#
#      ('P1_e_b ', 'Regiao onde mora') ('P1_g_b ', 'Regiao de origem')  \
# 4270                             NaN                             NaN
#
#       ('P1_g_c ', 'Mudou de Estado?') ('P1_h ', 'Nivel de Ensino')  ...  \
# 4270                              NaN                          NaN  ...
#
#      ('P8_d_2 ', 'Coletando e limpando os dados que uso para análise e modelagem.')  \
# 4270                                                NaN
#
#      ('P8_d_3 ', 'Entrando em contato com os times de negócio para definição do problema, identificar a solução e apresentação de resultados.')  \
# ...

# %%
pd.set_option('display.max_columns', 500)
st.tail(1)
# Out:
#                           ('P0', 'id')  ('P1_a ', 'Idade')  \
# 2644  037usz1h2yip96dgil4mhj037uszw1gk                27.0
#
#      ('P1_a_a ', 'Faixa idade') ('P1_b ', 'Genero')  \
# 2644                      25-29            Feminino
#
#      ('P1_e ', 'Estado onde mora') ('P1_e_a ', 'uf onde mora')  \
# 2644             Minas Gerais (MG)                          MG
#
#      ('P1_e_b ', 'Regiao onde mora') ('P1_g_b ', 'Regiao de origem')  \
# 2644                         Sudeste                             NaN
#
#       ('P1_g_c ', 'Mudou de Estado?') ('P1_h ', 'Nivel de Ensino')  \
# 2644                                0                Pós-graduação
#
#      ('P1_i ', 'Área de Formação')  \
# 2644                        Outras
#
#      ('P2_a ', 'Qual sua situação atual de trabalho?') ('P2_b ', 'Setor')  \
# 2644                Desempregado, buscando recolocação                NaN
#
#      ('P2_c ', 'Numero de Funcionarios')  ('P2_d ', 'Gestor?')  \
# ...

# %%
pd.set_option('display.max_rows',5000)
a=st1["('P1_b ', 'Genero')"]
pd.DataFrame(a)
# Out:
#        ('P1_b ', 'Genero')
# 0                Masculino
# 1                Masculino
# 2                Masculino
# 3                Masculino
# 4                 Feminino
# 5                 Feminino
# 6                Masculino
# 7                 Feminino
# 8                Masculino
# 9                 Feminino
# 10                Feminino
# 11               Masculino
# 12               Masculino
# 13               Masculino
# 14                Feminino
# 15               Masculino
# 16               Masculino
# 17               Masculino
# 18               Masculino
# 19                Feminino
# 20               Masculino
# 21               Masculino
# 22               Masculino
# 23                Feminino
# 24               Masculino
# 25                Feminino
# 26                Feminino
# 27                Feminino
# 28                Feminino
# 29               Masculino
# 30               Masculino
# 31               Masculino
# 32               Masculino
# ...

# %%
st.info(max_cols=True,verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2645 entries, 0 to 2644
# Data columns (total 356 columns):
#  #    Column                                                                                                                                                                                                                Dtype
# ---   ------                                                                                                                                                                                                                -----
#  0    ('P0', 'id')                                                                                                                                                                                                          object
# ...

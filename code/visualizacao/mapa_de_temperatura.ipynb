# %%
import numpy as np
import pandas as pd

# %%
train=pd.read_csv("/content/drive/MyDrive/agua/train.csv")
test=pd.read_csv("/content/drive/MyDrive/agua/test.csv")
sample=pd.read_csv("/content/drive/MyDrive/agua/sample_submission.csv")

# %%
train.tail()
# Out:
#                                                       id categoryA categoryB  \
# 12995  6dcf9c3ccaf0a92b107d6a78a2cd3ea363350b537444ec...    catA_3    catB_0
# 12996  e6241d096ea1b88d6e57a92fb6d984825c70de3a4b3ec5...    catA_8    catB_0
# 12997  081aa272b71b94d3cc665e1484a232b821e9997ed9cc80...   catA_25    catB_0
# 12998  c50903ae1d6ff475fa20e32fe39ce4429cc6285999a658...    catA_7    catB_0
# 12999  28ccbfbfd3a19bafd9cb68018aaa59b9ef2750883117ab...    catA_9    catB_0
#
#        categoryC categoryD categoryE categoryF   featureA   featureB  \
# 12995   catC_639    catD_0    catE_0    catF_0  75808.375   4.457840
# 12996   catC_445    catD_0    catE_0    catF_0  75808.375   4.457840
# 12997   catC_445    catD_0    catE_0    catF_1  75808.375   4.457840
# 12998  catC_2322    catD_0    catE_5    catF_0  18927.000  21.007457
# 12999  catC_2322    catD_0    catE_5    catF_0  18927.000  21.007457
#
#        featureC    featureD   featureE  featureF      featureG  featureH  \
# 12995  0.005718  122.299437  30.831906       0.0  2.806036e+12       0.0
# 12996  0.005718  122.299437  30.831906       0.0  2.806036e+12       0.0
# 12997  0.005718  122.299437  30.831906       0.0  2.806036e+12       0.0
# 12998  0.000387   18.148547  14.177182       0.0  2.526922e+11       0.0
# 12999  0.000387   18.148547  14.177182       0.0  2.526922e+11       0.0
#
#          featureI  compositionA  compositionB  compositionC  compositionD  \
# 12995  71176346.0           0.0         10.00         26.00           0.0
# 12996  71176346.0           0.0         10.00         26.00           0.0
# 12997  71176346.0           0.0         10.00         26.00           0.0
# 12998   2147000.0           0.0          9.24         13.13           0.0
# 12999   2147000.0           0.0          9.24         13.13           0.0
#
#        compositionE  compositionF  compositionG  compositionH  compositionI  \
# 12995         32.00           3.0          0.00          9.00         22.26
# 12996         32.00           3.0          0.00          9.00         22.26
# 12997         32.00           3.0          0.00          9.00         22.26
# 12998         35.88           1.7          0.73          1.45         28.12
# 12999         35.88           1.7          0.73          1.45         28.12
#
#        compositionJ     unit    result
# 12995         20.00   unit_1  0.008260
# 12996         20.00   unit_9  0.002395
# 12997         20.00  unit_12  0.150982
# 12998         37.83   unit_8  0.488908
# 12999         37.83  unit_10  0.232833

# %%
train.describe()
# Out:
#             featureA      featureB      featureC      featureD      featureE  \
# count   12936.000000  12936.000000  12936.000000  12936.000000  12936.000000
# mean   116559.238066      4.526278      0.132972    150.341104     26.446181
# std    146502.011917      3.180817      0.264148     75.093666      6.665619
# min    -83749.750000      1.064468      0.000000     18.148547      3.875411
# 25%     56744.750000      4.363288      0.005718    122.299437     24.625503
# 50%     75808.375000      4.457840      0.005718    122.299437     30.831906
# 75%     75808.375000      4.457840      0.032407    137.976566     30.831906
# max    582211.000000     25.982190      0.729194    511.475928     38.767234
#
#            featureF      featureG      featureH      featureI  compositionA  \
# count  13000.000000  1.293600e+04  12936.000000  1.293600e+04  12936.000000
# mean       0.217538  2.335365e+12     15.047186  5.020210e+07      0.164923
# std        2.380893  8.937298e+11     32.000372  2.412360e+07      0.743228
# min        0.000000  2.887150e+10      0.000000  5.300380e+05      0.000000
# 25%        0.000000  1.464509e+12      0.000000  2.586796e+07      0.000000
# 50%        0.000000  2.806036e+12      0.000000  5.094169e+07      0.000000
# 75%        0.000000  2.806036e+12      0.000000  7.117635e+07      0.000000
# max      100.000000  3.781699e+12     87.158924  7.117635e+07      4.000000
#
#        compositionB  compositionC  compositionD  compositionE  compositionF  \
# count  12936.000000  12936.000000  12936.000000  12936.000000  12936.000000
# mean       7.708228     23.627522      1.296887     32.038122      3.178698
# std        3.208687      6.433507      3.724154     11.098175      1.098585
# min        2.200000      0.000000      0.000000     12.780000      1.380000
# 25%        5.830000     17.700000      0.000000     30.000000      3.000000
# 50%       10.000000     26.000000      0.000000     32.000000      3.000000
# 75%       10.000000     26.000000      1.940000     32.000000      3.000000
# max       21.400000     44.050000     30.460000     62.300000      9.200000
#
#        compositionG  compositionH  compositionI  compositionJ        result
# count  12936.000000  12936.000000  12936.000000  12936.000000  13000.000000
# mean       2.024316     11.214700     23.386089     18.942594      0.144223
# std        2.964965      4.860118      5.937944      4.096265      0.224062
# min        0.000000      1.450000      0.760000      6.100000      0.000000
# 25%        0.000000      9.000000     22.260000     18.900000      0.003875
# 50%        0.000000      9.000000     22.260000     20.000000      0.027909
# 75%        2.000000     12.330000     27.250000     20.000000      0.168678
# max        7.900000     20.200000     47.830000     37.830000      1.000000

# %%
pd.set_option('display.float_format', lambda x: '%.2f' % x)
test.iloc[:, :-1].describe().T.sort_values(by='std', ascending=False)\
                     .style.background_gradient(cmap='YlOrBr')\
                     .bar(subset=["mean",], color='green')\
                     .bar(subset=["max"], color='#BB0000')
# Out:
# <style type="text/css">
# #T_dcce0_row0_col0, #T_dcce0_row1_col0, #T_dcce0_row1_col2, #T_dcce0_row1_col3, #T_dcce0_row1_col4, #T_dcce0_row1_col5, #T_dcce0_row1_col6, #T_dcce0_row2_col0, #T_dcce0_row2_col2, #T_dcce0_row2_col3, #T_dcce0_row2_col4, #T_dcce0_row2_col5, #T_dcce0_row2_col6, #T_dcce0_row3_col0, #T_dcce0_row3_col2, #T_dcce0_row3_col3, #T_dcce0_row3_col4, #T_dcce0_row3_col5, #T_dcce0_row3_col6, #T_dcce0_row4_col0, #T_dcce0_row4_col2, #T_dcce0_row4_col3, #T_dcce0_row4_col4, #T_dcce0_row4_col5, #T_dcce0_row4_col6, #T_dcce0_row5_col0, #T_dcce0_row5_col2, #T_dcce0_row5_col3, #T_dcce0_row5_col4, #T_dcce0_row5_col5, #T_dcce0_row5_col6, #T_dcce0_row6_col0, #T_dcce0_row6_col2, #T_dcce0_row6_col3, #T_dcce0_row6_col4, #T_dcce0_row6_col5, #T_dcce0_row6_col6, #T_dcce0_row7_col0, #T_dcce0_row7_col2, #T_dcce0_row7_col3, #T_dcce0_row7_col4, #T_dcce0_row7_col5, #T_dcce0_row7_col6, #T_dcce0_row8_col0, #T_dcce0_row8_col2, #T_dcce0_row8_col3, #T_dcce0_row8_col4, #T_dcce0_row8_col5, #T_dcce0_row8_col6, #T_dcce0_row9_col0, #T_dcce0_row9_col2, #T_dcce0_row9_col3, #T_dcce0_row9_col4, #T_dcce0_row9_col5, #T_dcce0_row9_col6, #T_dcce0_row10_col0, #T_dcce0_row10_col2, #T_dcce0_row10_col3, #T_dcce0_row10_col4, #T_dcce0_row10_col5, #T_dcce0_row10_col6, #T_dcce0_row11_col0, #T_dcce0_row11_col2, #T_dcce0_row11_col3, #T_dcce0_row11_col4, #T_dcce0_row11_col5, #T_dcce0_row11_col6, #T_dcce0_row12_col0, #T_dcce0_row12_col2, #T_dcce0_row12_col3, #T_dcce0_row12_col4, #T_dcce0_row12_col5, #T_dcce0_row12_col6, #T_dcce0_row13_col0, #T_dcce0_row13_col2, #T_dcce0_row13_col3, #T_dcce0_row13_col4, #T_dcce0_row13_col5, #T_dcce0_row13_col6, #T_dcce0_row14_col0, #T_dcce0_row14_col2, #T_dcce0_row14_col3, #T_dcce0_row14_col4, #T_dcce0_row14_col5, #T_dcce0_row14_col6, #T_dcce0_row15_col0, #T_dcce0_row15_col2, #T_dcce0_row15_col3, #T_dcce0_row15_col4, #T_dcce0_row15_col5, #T_dcce0_row15_col6, #T_dcce0_row16_col0, #T_dcce0_row16_col2, #T_dcce0_row16_col3, #T_dcce0_row16_col4, #T_dcce0_row16_col5, #T_dcce0_row16_col6, #T_dcce0_row17_col0, #T_dcce0_row17_col2, #T_dcce0_row17_col3, #T_dcce0_row17_col4, #T_dcce0_row17_col5, #T_dcce0_row17_col6, #T_dcce0_row18_col2, #T_dcce0_row18_col3, #T_dcce0_row18_col4, #T_dcce0_row18_col5, #T_dcce0_row18_col6 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_dcce0_row0_col1 {
#   background-color: #662506;
#   color: #f1f1f1;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,green 100.0%, transparent 100.0%);
# }
# #T_dcce0_row0_col2, #T_dcce0_row0_col3, #T_dcce0_row0_col4, #T_dcce0_row0_col5, #T_dcce0_row0_col6, #T_dcce0_row18_col0 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# #T_dcce0_row0_col7 {
#   background-color: #662506;
#   color: #f1f1f1;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#BB0000 100.0%, transparent 100.0%);
# }
# #T_dcce0_row1_col1, #T_dcce0_row2_col1, #T_dcce0_row3_col1, #T_dcce0_row4_col1, #T_dcce0_row5_col1, #T_dcce0_row6_col1, #T_dcce0_row7_col1, #T_dcce0_row8_col1, #T_dcce0_row9_col1, #T_dcce0_row10_col1, #T_dcce0_row11_col1, #T_dcce0_row12_col1, #T_dcce0_row13_col1, #T_dcce0_row14_col1, #T_dcce0_row15_col1, #T_dcce0_row16_col1, #T_dcce0_row17_col1 {
#   background-color: #ffffe5;
#   color: #000000;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,green 0.0%, transparent 0.0%);
# }
# #T_dcce0_row1_col7, #T_dcce0_row2_col7, #T_dcce0_row3_col7, #T_dcce0_row4_col7, #T_dcce0_row5_col7, #T_dcce0_row6_col7, #T_dcce0_row7_col7, #T_dcce0_row8_col7, #T_dcce0_row9_col7, #T_dcce0_row10_col7, #T_dcce0_row11_col7, #T_dcce0_row12_col7, #T_dcce0_row13_col7, #T_dcce0_row14_col7, #T_dcce0_row15_col7, #T_dcce0_row16_col7, #T_dcce0_row17_col7 {
#   background-color: #ffffe5;
#   color: #000000;
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#BB0000 0.0%, transparent 0.0%);
# }
# #T_dcce0_row18_col1, #T_dcce0_row18_col7 {
#   background-color: #ffffe5;
#   color: #000000;
#   width: 10em;
#   height: 80%;
# }
# </style>
# <table id="T_dcce0_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >count</th>
#       <th class="col_heading level0 col1" >mean</th>
#       <th class="col_heading level0 col2" >std</th>
#       <th class="col_heading level0 col3" >min</th>
#       <th class="col_heading level0 col4" >25%</th>
#       <th class="col_heading level0 col5" >50%</th>
#       <th class="col_heading level0 col6" >75%</th>
#       <th class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dcce0_level0_row0" class="row_heading level0 row0" >featureG</th>
#       <td id="T_dcce0_row0_col0" class="data row0 col0" >6957.000000</td>
#       <td id="T_dcce0_row0_col1" class="data row0 col1" >2196448071286.044678</td>
#       <td id="T_dcce0_row0_col2" class="data row0 col2" >992580724845.943481</td>
#       <td id="T_dcce0_row0_col3" class="data row0 col3" >28871503534.392899</td>
#       <td id="T_dcce0_row0_col4" class="data row0 col4" >1464508831011.810059</td>
#       <td id="T_dcce0_row0_col5" class="data row0 col5" >2757620259273.379883</td>
#       <td id="T_dcce0_row0_col6" class="data row0 col6" >2806036371233.859863</td>
#       <td id="T_dcce0_row0_col7" class="data row0 col7" >3781698549834.740234</td>
#     </tr>
#     <tr>
#       <th id="T_dcce0_level0_row1" class="row_heading level0 row1" >featureI</th>
#       <td id="T_dcce0_row1_col0" class="data row1 col0" >6957.000000</td>
#       <td id="T_dcce0_row1_col1" class="data row1 col1" >47318042.774615</td>
#       <td id="T_dcce0_row1_col2" class="data row1 col2" >25620342.439357</td>
#       <td id="T_dcce0_row1_col3" class="data row1 col3" >530038.000000</td>
#       <td id="T_dcce0_row1_col4" class="data row1 col4" >25867961.000000</td>
#       <td id="T_dcce0_row1_col5" class="data row1 col5" >50941692.000000</td>
#       <td id="T_dcce0_row1_col6" class="data row1 col6" >71176346.000000</td>
#       <td id="T_dcce0_row1_col7" class="data row1 col7" >71176346.000000</td>
#     </tr>
#     <tr>
#       <th id="T_dcce0_level0_row2" class="row_heading level0 row2" >featureA</th>
#       <td id="T_dcce0_row2_col0" class="data row2 col0" >6957.000000</td>
#       <td id="T_dcce0_row2_col1" class="data row2 col1" >109832.747125</td>
#       <td id="T_dcce0_row2_col2" class="data row2 col2" >141143.226320</td>
#       <td id="T_dcce0_row2_col3" class="data row2 col3" >-83749.750000</td>
#       <td id="T_dcce0_row2_col4" class="data row2 col4" >21256.750000</td>
#       <td id="T_dcce0_row2_col5" class="data row2 col5" >75808.375000</td>
#       <td id="T_dcce0_row2_col6" class="data row2 col6" >75808.375000</td>
#       <td id="T_dcce0_row2_col7" class="data row2 col7" >582211.000000</td>
#     </tr>
#     <tr>
#       <th id="T_dcce0_level0_row3" class="row_heading level0 row3" >featureD</th>
#       <td id="T_dcce0_row3_col0" class="data row3 col0" >6957.000000</td>
#       <td id="T_dcce0_row3_col1" class="data row3 col1" >149.065796</td>
#       <td id="T_dcce0_row3_col2" class="data row3 col2" >77.640557</td>
#       <td id="T_dcce0_row3_col3" class="data row3 col3" >14.548292</td>
#       <td id="T_dcce0_row3_col4" class="data row3 col4" >107.127967</td>
#       <td id="T_dcce0_row3_col5" class="data row3 col5" >122.299437</td>
#       <td id="T_dcce0_row3_col6" class="data row3 col6" >137.976566</td>
#       <td id="T_dcce0_row3_col7" class="data row3 col7" >377.379590</td>
#     </tr>
#     <tr>
#       <th id="T_dcce0_level0_row4" class="row_heading level0 row4" >featureH</th>
#       <td id="T_dcce0_row4_col0" class="data row4 col0" >6957.000000</td>
#       <td id="T_dcce0_row4_col1" class="data row4 col1" >14.509976</td>
#       <td id="T_dcce0_row4_col2" class="data row4 col2" >30.740971</td>
#       <td id="T_dcce0_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_dcce0_row4_col4" class="data row4 col4" >0.000000</td>
#       <td id="T_dcce0_row4_col5" class="data row4 col5" >0.000000</td>
#       <td id="T_dcce0_row4_col6" class="data row4 col6" >0.000000</td>
#       <td id="T_dcce0_row4_col7" class="data row4 col7" >87.158924</t

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
def plot_correlation_heatmap(df: pd.core.frame.DataFrame, title_name: str='Train correlation') -> None:
    """Draws the correlation heatmap plot.
    
    Args:
        df: train or test dataframes
        title_name: 'Train' or 'Test' (default 'Train correlation')
        
    Returns:
        subplots of size (len(col_list), 2)
    """

    corr = df.corr()
    fig, axes = plt.subplots(figsize=(10, 5))
    mask = np.zeros_like(corr)
    mask[np.triu_indices_from(mask)] = True
    sns.heatmap(corr, mask=mask, linewidths=.5, cmap='Reds', annot=True)
    plt.title(title_name)
    plt.show()

plot_correlation_heatmap(x, 'Train Dataset Correlation')
plot_correlation_heatmap(mx, 'Test Dataset Correlation')
